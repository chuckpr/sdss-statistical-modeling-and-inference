# %% [markdown]
# [![Open In Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/chuckpr/sdss-statistical-modeling-and-inference/blob/main/00-jupyter-lab/lectures/03_jupyter-cell-exectution.ipynb)

# %% [markdown]
# ## ⚠ Execution order matters ⚠️

# %%
library('tidyverse')
options(repr.plot.height = 6, repr.plot.width = 9)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.1
# ✔ tidyr   1.1.1     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
p = ggplot(mpg, aes(x = displ, y = cty)) + geom_point(size = 5)

p
# Out:
# plot without title

# %%
p = p + geom_point(size = 1, color = 'yellow')

p
# Out:
# plot without title

# %%
p = p + geom_point(size = 3, color = 'blue')

p
# Out:
# plot without title

# %%
p
# Out:
# plot without title

# %% [markdown]
# Cell numbers persist when you open a "stopped" notebook. To refresh all your cell execution numbers, select `Restart Kernel and Clear All Outputs` from the `Kernel` menu

# %%
p
# Out:
# plot without title

# %% [markdown]
# ## What to do if you get a `Kernel Restarting` error...

# %% [markdown]
# ![](https://i.stack.imgur.com/ETXDw.png)

# %% [markdown]
# 1. Go to the `Kernel` menu.
# 1. Select `Restart Kernel and Run All Cells`

# %% [markdown]
# ![image.png](attachment:acf7aa92-da72-446c-9bb3-968fd4978a38.png)
